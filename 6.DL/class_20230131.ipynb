# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_ = np.arange(-4, 4.1, 0.1)
y_ = x_ ** 2

# %%
plt.figure(figsize=(6,4))
plt.plot(x_, y_, linewidth=3)

x = [4]
y = [x[-1] ** 2]
lr = 0.90

for _ in range(20):
    dy_dx = 2 * x[-1]
    x.append(x[-1] - lr * dy_dx)
    y.append(x[-1] ** 2)
plt.plot(x, y, c='r', marker='o', linewidth=1, markersize=5)
plt.scatter(x[0], y[0], c='y', s = 100)
plt.scatter(x[-1], y[-1], c='black', s = 100)
plt.show()

# %%
# 공부 시간 X와 성적 y의 넘파이 배열을 만듭니다.
x = np.array([2, 4, 6, 8])
y = np.array([81, 93, 91, 97])

plt.scatter(x, y)
plt.show()

# %%
# 기울기 a와 절편 b의 값을 초기화합니다.
a = 0
b = 0

# 학습률을 정합니다.
lr = 0.031

# 몇 번 반복될지 설정합니다. 
iter = 500

fig, ax = plt.subplots(1, 5, figsize=(12,4))
x_fit = np.arange(2, 10)

j = 0
for i in range(iter):
    y_hat = a * x + b
    error = (y - y_hat)

    a_diff = -(2 / len(x)) * sum(error * x)
    b_diff = -(2 / len(x)) * sum(error)

    a = a - lr * a_diff
    b = b - lr * b_diff

    if i % 100 == 0:
        print(f'iter = {i}, slope = {a}, bias = {b}')
        ax[j].scatter(x, y)
        ax[j].plot(x_fit, b + a * x_fit, 'r')
        ax[j].set_ylim(60, 100)
        j = j + 1
plt.show()
# Out:
# iter = 0, slope = 28.768, bias = 5.611
# iter = 100, slope = 6.919894336535791, bias = 51.43884386234357
# iter = 200, slope = 3.981575235110366, bias = 68.96507899001037
# iter = 300, slope = 2.912250546332734, bias = 75.34635058073845
# iter = 400, slope = 2.52291643807648, bias = 77.6697300322247

# %%
from tensorflow import keras

# %%
model = keras.Sequential(name='regression')
model.add(keras.layers.Dense(1, input_shape=(1,), activation='linear', name='output'))

model.summary()
# Out:
# Model: "regression"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  output (Dense)              (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='sgd')

# %%
model.fit(x, y, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 369ms/step - loss: 8695.1621
# Epoch 2/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2107.6484
# Epoch 3/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1134.7749
# Epoch 4/500
# 1/1 [==============================] - 0s 5ms/step - loss: 986.5866
# Epoch 5/500
# 1/1 [==============================] - 0s 6ms/step - loss: 959.5583
# Epoch 6/500
# 1/1 [==============================] - 0s 6ms/step - loss: 950.3595
# Epoch 7/500
# 1/1 [==============================] - 0s 5ms/step - loss: 943.8133
# Epoch 8/500
# 1/1 [==============================] - 0s 5ms/step - loss: 937.6902
# Epoch 9/500
# 1/1 [==============================] - 0s 6ms/step - loss: 931.6628
# Epoch 10/500
# 1/1 [==============================] - 0s 5ms/step - loss: 925.6826
# Epoch 11/500
# 1/1 [==============================] - 0s 6ms/step - loss: 919.7423
# Epoch 12/500
# ...

# %%
slope = model.get_weights()[0][0]
intercept = model.get_weights()[1]

print(slope, intercept)
# Out:
# [4.8229876] [63.94389]

# %%
x = np.array([[2,0],[4,4],[6,2],[8,3]])
y = np.array([81,93,91,97])

model = keras.Sequential()

model.add(keras.layers.Dense(1, input_dim=2, activation='linear'))
model.compile(optimizer='sgd', loss='mse')

model.fit(x,y,epochs=2000)

hour = 7
private_class = 4
prediction = model.predict([[hour, private_class]])

print(f'hour: {hour}, private_class: {private_class}, prediction : {prediction}')
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 257ms/step - loss: 9982.0146
# Epoch 2/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 1556.8154
# Epoch 3/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 958.8412
# Epoch 4/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 911.3894
# Epoch 5/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 902.6907
# Epoch 6/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 896.7522
# Epoch 7/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 891.0424
# Epoch 8/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 885.3830
# Epoch 9/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 879.7611
# Epoch 10/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 874.1755
# Epoch 11/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 868.6260
# Epoch 12/2000
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x = np.array([2, 4, 6, 8, 10, 12, 14])
y = np.array([0, 0, 0, 1, 1, 1, 1])

# %%
model = Sequential()
model.add(Dense(1, input_dim=1, activation='sigmoid'))

# 교차 엔트로피 오차 함수를 이용하기 위하여 'binary_crossentropy'로 설정합니다. 
model.compile(optimizer='sgd' ,loss='binary_crossentropy')
model.fit(x, y, epochs=5000)
# Out:
# Epoch 1/5000
# 1/1 [==============================] - 0s 368ms/step - loss: 10.8845
# Epoch 2/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 10.4874
# Epoch 3/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 10.0904
# Epoch 4/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 9.6937
# Epoch 5/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 9.2973
# Epoch 6/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 8.9011
# Epoch 7/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 8.5052
# Epoch 8/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 8.1097
# Epoch 9/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 7.7147
# Epoch 10/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 7.3202
# Epoch 11/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9263
# Epoch 12/5000
# ...

# %%
def sigmoid(x, a, b):
    y = 1 / (1 + np.exp(-(a * x + b)))
    return y

plt.scatter(x, y)
plt.plot(x, model.predict(x),'r')

x_arange = np.arange(0, 15, 0.1)
y_hat = sigmoid(x_arange, 6, -42)

plt.plot(x_arange, y_hat, c='g')
plt.show()
# Out:
# 1/1 [==============================] - 0s 26ms/step

# %%
hour = 7
prediction = model.predict([hour])

print("%.f시간을 공부할 경우, 합격 예상 확률은 %.01f%%입니다" % (hour, prediction * 100))
# Out:
# 1/1 [==============================] - 0s 45ms/step
# 7시간을 공부할 경우, 합격 예상 확률은 59.8%입니다

# %%
from IPython.display import clear_output

# %%
def sigmoid(x):
    y = 1 / (1 + np.exp(-x))
    return y

def updates(x, y, a, b, lr):
    a_diff = x * (sigmoid(a * x + b) - y)
    b_diff = sigmoid(a * x + b) - y

    a = a - lr * a_diff
    b = b - lr * b_diff

    return a, b

# %%
a = 0
b = 0
lr = 0.3

x_plot = np.arange(0,16,0.1)

for i in range(2001):
    for x_data, y_data in zip(x, y):
        # a_diff = x_data * (sigmoid(a * x_data + b) - y_data)
        # b_diff = sigmoid(a * x_data + b) - y_data

        # a = a - lr * a_diff
        # b = b - lr * b_diff
        a, b = updates(x_data, y_data, a, b, lr)
    if i % 100 == 0:
        clear_output()
        print(f'epoch = {i}, slope = {a}, intercept = {b}')
        plt.plot(x, y, 'bo')
        plt.plot(x_plot, sigmoid(a * x_plot + b), 'r')
        plt.xlim(0, 15)
        plt.ylim(-0.1, 1.1)
        plt.show()
        plt.pause(1)
# Out:
# epoch = 2000, slope = 4.0295583730479105, intercept = -27.887167843051593

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x = np.array([2, 4, 6, 8, 10, 12, 14])
y = np.array([0, 0, 0, 1, 1, 1, 1])

model = Sequential()
model.add(Dense(1, input_dim=1, activation='sigmoid'))

model.compile(optimizer='sgd' ,loss='binary_crossentropy')
model.fit(x, y, epochs=5000)

plt.scatter(x, y)
plt.plot(x, model.predict(x),'r')
plt.show()

hour = 7
prediction = model.predict([hour])

print("%.f시간을 공부할 경우, 합격 예상 확률은 %.01f%%입니다" % (hour, prediction * 100))
# Out:
# Epoch 1/5000
# 1/1 [==============================] - 0s 313ms/step - loss: 8.4834
# Epoch 2/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 8.0878
# Epoch 3/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 7.6927
# Epoch 4/5000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.2982
# Epoch 5/5000
# 1/1 [==============================] - 0s 4ms/step - loss: 6.9042
# Epoch 6/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.5109
# Epoch 7/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.1186
# Epoch 8/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.7272
# Epoch 9/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3371
# Epoch 10/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9486
# Epoch 11/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.5620
# Epoch 12/5000
# ...
