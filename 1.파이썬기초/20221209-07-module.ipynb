# %% [markdown]
# # Chap07 모듈

# %% [markdown]
# ## 07 - 1 표준 모듈

# %%
import math

print(math.ceil(10.254))
print(math.floor(10.254))
# Out:
# 11
# 10

# %%
import random as rn
print("random moule -- ")

print("random() ", rn.random())
print("uniform(10, 20) ", rn.uniform(10, 20))
print("randrange(10) ", rn.randrange(10))
# Out:
# random moule --
# random()  0.4648938620973121
# uniform(10, 20)  13.184651278536775
# randrange(10)  6

# %%
import os

print('현재 디렉토리 확인 : ', os.getcwd())
# os.mkdir('testdir')
print('현재 디렉토리 리스트 : ', os.listdir())
print('디렉토리 파일명 : ', os.listdir('testdir'))
os.chdir('testdir')
print('현재 디렉토리 확인 : ', os.getcwd())
# Out:
# 현재 디렉토리 확인 :  C:\Users\YGL\YGL
# 현재 디렉토리 리스트 :  ['.ipynb_checkpoints', '20221206-day1.ipynb', '20221207_day2.ipynb', '20221208-day3.ipynb', '20221209-07-module.ipynb', '20221209-day4.ipynb', 'basic.txt', 'calc.ipynb', 'calc.py', 'info.txt', 'testdir', 'test_score_program.py', 'Untitled.ipynb', '이기환_hw1.ipynb', '이기환_hw2.ipynb', '이기환_hw3.ipynb']
# 디렉토리 파일명 :  []
# 현재 디렉토리 확인 :  C:\Users\YGL\YGL\testdir

# %%
# ./ -> 현재 디렉토리
# ../ ->상위 디렉토리
# 디렉토리명/ -> 하위 디렉토리
# os별 절대 경로 규칙이 다르므로 사용하지 않는 것이 좋음
file = open('../basic.txt', 'r')
file.close()

# %%
from urllib import request

target = request.urlopen("https://google.com")
output = target.read()
target.close()
print(output)
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="ko"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/logos/doodles/2022/seasonal-holidays-2022-6753651837109831.3-law.gif" itemprop="image"><meta content="2022 &#50672;&#47568;&#50672;&#49884;" property="twitter:title"><meta content=" " property="twitter:description"><meta content=" " property="og:description"><meta content="summary_large_image" property="twitter:card"><meta content="@GoogleDoodles" property="twitter:site"><meta content="https://www.google.com/logos/doodles/2022/seasonal-holidays-2022-6753651837109831.2-2xa.gif" property="twitter:image"><meta content="https://www.google.com/logos/doodles/2022/seasonal-holidays-2022-6753651837109831.2-2xa.gif" property="og:image"><meta content="1150" property="og:image:width"><meta content="460" property="og:image:height"><meta content="https://www.google.com/logos/doodles/2022/seasonal-holidays-2022-6753651837109831.
# ...

# %%
from bs4 import BeautifulSoup
from urllib import request

target = request.urlopen("https://google.com")
#output = target.read()
soup = BeautifulSoup(target)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# alabaster                     0.7.12
# anaconda-client               1.11.0
# anaconda-navigator            2.3.2
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.11.7
# astropy                       5.1
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# bcrypt                        3.2.0
# beautifulsoup4                4.11.1
# binaryornot                   0.4.4
# ...
