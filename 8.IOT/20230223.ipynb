# %% [markdown]
# # Linux 설치하기

# %% [markdown]
# 1. Ubuntu 20.04.5 LTS 다운로드
# 2. VM으로 설치
# 3. 상위 버전 업데이트 금지

# %% [markdown]
# # 터미널

# %% [markdown]
# - ubuntu@Virtualbox
#     `username`@`hostname`
#
# - sudo
#     관리자권한(root)으로 동작
#
# - sudo apt update
#     update 동작 수행
#
# - sudo apt upgrade
#     upgrade 동작 수행

# %% [markdown]
# # 리눅스의 개요

# %% [markdown]
# - 리눅스 = 무료 유닉스 (1969 AT&T Unix)
# - 1991년 '리누스 토르발스'가 버전 0.01을 최초로 작성
# - 1992년 0.02 버전을 공개하면서 시작됨
# - 리누스 토르발스는 커널(Kernel)만 개발함
# - 배포판의 구성
#     - 하드웨어 - 커널 - 셀 - 응용 프로그램

# %% [markdown]
# # GNU 프로젝트
# - `GNU is Not Unix`

# %% [markdown]
# - 1984년에 리차트 스톨만에 의해서 GNU 프로젝트가 시작
# - 목표는 '모두가 공유할 수 있는 소프트웨어'를 만드는 것
# - 리차드 스톨만은 1985년에 자유 소프트웨어 재단(FSF, Free Software Foundation)을 설립
# - 목표는 GNU 프로젝트에서 제작한 소프트웨어를 지원함으로써 컴퓨터 프로그램의 복제, 변경, 소스 코드의 사용에 대한 제한을 철폐하는 것
# - GPL(General Public License)을 따름.

# %% [markdown]
# # 리눅스 필수 개념과 명령어

# %% [markdown]
# ## 시작과 종료

# %% [markdown]
# - 종료하는 방법
#   - shut down -P now
#   -
# - 재시작하는 방법
#   - shut down -r now

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Vi 명령어

# %% [markdown]
# ![image.png](attachment:image.png)
